# %%
import pandas as pd

# %%
df = pd.read_csv('raw.csv')

# %%
df[df['HS Code'] == 203294000]
# Out:
#          Partner  Unnamed: 1      HS Code      Product     2015     2016  \
# 5         Mexico         1.5  203294000.0  SWN MT, FRZ   97,551   94,346
# 13         Japan         1.2  203294000.0  SWN MT, FRZ  466,334  405,845
# 23  Korea, South         1.1  203294000.0  SWN MT, FRZ  356,510  276,723
# 35        Canada         1.2  203294000.0  SWN MT, FRZ   25,748   24,700
# 41         China         1.1  203294000.0  SWN MT, FRZ   49,375  159,582
#
#        2017     2018     2019     2020     2021     2022     2023     2024  \
# 5    86,483   66,567   67,855   68,558   79,633   87,375   98,215  111,077
# 13  428,830  415,640  358,034  389,136  374,735  296,798  428,314  496,361
# 23  374,783  535,624  461,657  347,770  413,250  474,554  520,343  624,501
# 35   27,710   28,957   34,433   46,435   46,044   36,089   36,323   24,998
# 41  161,358  182,066  312,581  882,320  543,920  441,155  330,941  309,480
#
# ...

# %%
df[df['HS Code'] == 203210000]
# Out:
#          Partner  Unnamed: 1      HS Code      Product   2015   2016   2017  \
# 10        Mexico         1.1  203210000.0  SWN CARC,FZ    505  4,487  1,207
# 19         Japan         1.8  203210000.0  SWN CARC,FZ  1,392     68      3
# 30  Korea, South         1.8  203210000.0  SWN CARC,FZ    197      0     11
# 39        Canada         1.6  203210000.0  SWN CARC,FZ     13      0      0
# 42         China         1.2  203210000.0  SWN CARC,FZ  9,036  7,493  1,270
#
#    2018     2019     2020    2021    2022    2023    2024  \
# 10  238      249      497   1,105     781   2,015     270
# 19   30       15        0     249       0       0      12
# 30   13      547        6     355     759     526     238
# 39    0        0        0       0       0       0      34
# 42  245  447,733  400,665  50,039  40,878  29,922  25,051
#
#    Period/Period %  Change (Value) Reporter Code Partner Code Product Code  \
# 10                             -87            US           MX    203210000
# ...

# %%
df[df['HS Code'] == 203229000]
# Out:
#          Partner  Unnamed: 1      HS Code          Product    2015     2016  \
# 9         Mexico         1.9  203229000.0  HM/SH,X PRC,FRZ  55,266   43,661
# 18         Japan         1.7  203229000.0  HM/SH,X PRC,FRZ   4,007    1,931
# 26  Korea, South         1.4  203229000.0  HM/SH,X PRC,FRZ  14,011    6,487
# 38        Canada         1.5  203229000.0  HM/SH,X PRC,FRZ      87       13
# 43         China         1.3  203229000.0  HM/SH,X PRC,FRZ  50,311  105,228
#
#       2017    2018    2019     2020     2021    2022    2023   2024  \
# 9   41,182  41,330  43,214   36,729    5,323   3,895   2,842  3,416
# 18   1,791     627     789    1,737    1,831   2,760   3,212    289
# 26   3,580   8,096   6,542    7,151   19,095   9,967   3,965  4,262
# 38      52     173     360    1,420      723     500   1,512    274
# 43  69,428  14,684  86,056  320,686  234,105  14,159  11,030  6,389
#
#    Period/Period %  Change (Value) Reporter Code Partner Code Product Code  \
# ...

# %%
df_offal = pd.read_csv('offal.csv')

# %%
df_offal[df_offal['HS Code'] == 206490030]
# Out:
#          Partner  Unnamed: 1      HS Code          Product    2015     2016  \
# 1          China         1.1  206490030.0  SWN OFL,FZ,FEET  86,067  129,103
# 16        Mexico         1.5  206490030.0  SWN OFL,FZ,FEET  12,693   11,392
# 26   Philippines         1.4  206490030.0  SWN OFL,FZ,FEET     587    1,736
# 38  Korea, South         1.1  206490030.0  SWN OFL,FZ,FEET   9,710    7,725
# 53         Japan         1.6  206490030.0  SWN OFL,FZ,FEET       0      249
#
#        2017    2018     2019     2020     2021     2022     2023     2024  \
# 1   149,678  84,025  139,356  271,547  401,778  472,991  410,273  366,145
# 16   11,727  11,316    8,378    6,397    7,755    4,675    5,792    7,734
# 26    1,689   5,363    1,875    1,630      776      996    1,004    6,231
# 38   10,650  13,772    6,891    3,961    7,013    5,029    2,612    5,656
# 53      504     558      279      233       75      206       54      162
#
# ...

# %%
df_offal[df_offal['HS Code'] == 206490090]
# Out:
#          Partner  Unnamed: 1      HS Code           Product    2015     2016  \
# 2          China         1.2  206490090.0  SWN OFL,FZ,OTHER  28,347   24,116
# 13        Mexico         1.2  206490090.0  SWN OFL,FZ,OTHER  72,818  107,857
# 23   Philippines         1.1  206490090.0  SWN OFL,FZ,OTHER  11,388   12,769
# 34        Canada         1.1  206490090.0  SWN OFL,FZ,OTHER   9,500    8,654
# 40  Korea, South         1.3  206490090.0  SWN OFL,FZ,OTHER   8,323    5,389
# 48         Japan         1.1  206490090.0  SWN OFL,FZ,OTHER  12,923   15,632
#
#       2017    2018    2019    2020     2021     2022     2023     2024  \
# 2   31,284  17,940  23,696  82,959  107,434  157,732  191,316  129,680
# 13  93,527  66,083  62,680  44,748   41,098   32,129   34,964   35,470
# 23  13,471  14,888  10,047  12,794   19,856   19,421   16,300   28,667
# 34  11,031  11,146  12,878  14,208   18,406   16,318   14,507   17,020
# 40   5,590   9,333   6,601   7,291    6,308    6,637    4,832    5,049
# ...
